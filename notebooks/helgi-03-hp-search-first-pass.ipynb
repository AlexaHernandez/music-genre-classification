# %% [markdown]
# # Genre classification using lyrics

# %% [markdown]
# In this notebook, we build upon findings from helgi-02-scraped-lyrics-v1.ipynb. Recall:
# * Songs with 70 or less characters can be removed (746 songs). About 84% of these are instrumentals or don't have the lyrics specified
# * Songs 76479, 7991, 13345, 13327, 23981, 78729 and 72425 can be removed since they are tabs, not lyrics

# %%
import random

import numpy as np
import pandas as pd

random_state = 1111
np.random.seed(random_state)
random.seed(random_state)

import sklearn.linear_model
import sklearn.naive_bayes

import seaborn as sns
from matplotlib import pyplot as plt

import sys
sys.path.append("../")

from libs.processing import (
    Lemmatizer,
    Stemmer,
    StopWords,
    fit_vectorizer,
    random_search,
    choose_random_params
)
# Out:
# E:\Repos\comp550-final-project\venv\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Load and prepare data

# %%
df = pd.read_csv('E:\\Repos\\comp550-final-project\\data\\scraped-lyrics-v1.csv')

# %%
print('Initial data count per genre:', end='\n\n')
print(df.groupby('genre').count().lyrics, end='\n\n')
print(f'Total: {len(df)}')
# Out:
# Initial data count per genre:
#
# genre
# Alternative Rock    8000
# Country             8000
# Hard Rock           8000
# Heavy Metal         8000
# Hip-Hop             8000
# Indie               8000
# Pop                 8000
# R&B                 8000
# Rock                8000
# Soul                8000
# Name: lyrics, dtype: int64
#
# Total: 80000

# %%
# Only keep songs whose lyrics are 70 or more characters
df = df[df['lyrics'].str.len() >= 70]

# Remove tabs
df = df.drop(labels=[76479, 7991, 13345, 13327, 23981, 78729, 72425])

print('Data remaining after filtration:', end='\n\n')
print(df.groupby('genre').count().lyrics, end='\n\n')
print(f'Total: {len(df)}')
# Out:
# Data remaining after filtration:
#
# genre
# Alternative Rock    7897
# Country             7984
# Hard Rock           7896
# Heavy Metal         7879
# Hip-Hop             7973
# Indie               7885
# Pop                 7939
# R&B                 7958
# Rock                7911
# Soul                7925
# Name: lyrics, dtype: int64
#
# Total: 79247

# %%
data_ratio = 1 # How much of the data to use
df = df.reset_index(drop=True)
df.index.to_numpy()
splits = [0.7, 0.85]

indices = sklearn.utils.shuffle(df.index.to_numpy(), random_state=1234)
n_data_used = int(data_ratio*len(indices))

all_data = []
for i in indices[ : n_data_used]:
    song = df.iloc[i]
    all_data.append((song.lyrics, song.genre))

all_data = np.array(all_data, dtype=object)
n = len(all_data)
data = {
    'X_train_raw': all_data[:int(splits[0]*n), 0],
    'y_train': all_data[:int(splits[0]*n), 1],
    'X_valid_raw': all_data[int(splits[0]*n):int(splits[1]*n), 0],
    'y_valid': all_data[int(splits[0]*n): int(splits[1]*n), 1],
    'X_test_raw': all_data[int(splits[1]*n):, 0],
    'y_test': all_data[int(splits[1]*n):, 1]
}

print(f'Ratio of data used: {data_ratio}*{len(indices)} = {n_data_used}')
# Out:
# Ratio of data used: 1*79247 = 79247

# %% [markdown]
# ## Validation set hyper-parameter search across models

# %%
search_params = {
    'data': {
        'tokenizer': [Lemmatizer, Stemmer],
        'stop_words': [StopWords('nltk_english'), StopWords('None', [])],
        'min_df': [0, 1, 2, 3] # Minimum token frequency
    },
    'model': {
        'logistic_regression': {
            'eta0': [1e-3, 1e-2, 1e-1], # learning rate
            'alpha': [1e-3, 1e-2, 1e-1], # regularization
            'max_iter': np.arange(start=1, stop=10), # epochs
            'loss': ['log'],
            'random_state': [random_state]
        },
        'naive_bayes': {
            'alpha': np.arange(start=0.1, stop=1.1, step=0.1)
        },
        'random_forest': {
            'n_estimators': np.arange(start=10, stop=1000, step=10),
            'max_depth': np.arange(start=1, stop=10, step=2),
            'random_state': [random_state]
        }
    }
}

models = {
    'logistic_regression': sklearn.linear_model.SGDClassifier,
    'naive_bayes': sklearn.naive_bayes.MultinomialNB,
    'random_forest': sklearn.ensemble.RandomForestClassifier
}

# %%
data_sets, results = random_search(models, data, search_params, n_datasets=4, n_models=4, multi_label=False)
# Out:
# Data set variation 1/4
# 	Fitting vectorizer...
# 	logistic_regression 1/4
# 	logistic_regression 2/4
# 	logistic_regression 3/4
# 	logistic_regression 4/4
# 	naive_bayes 1/4
# 	naive_bayes 2/4
# 	naive_bayes 3/4
# 	naive_bayes 4/4
# 	random_forest 1/4
# 	random_forest 2/4
# 	random_forest 3/4
# 	random_forest 4/4
# Data set variation 2/4
# 	Fitting vectorizer...
# 	logistic_regression 1/4
# 	logistic_regression 2/4
# 	logistic_regression 3/4
# 	logistic_regression 4/4
# 	naive_bayes 1/4
# 	naive_bayes 2/4
# 	naive_bayes 3/4
# 	naive_bayes 4/4
# 	random_forest 1/4
# 	random_forest 2/4
# 	random_forest 3/4
# 	random_forest 4/4
# Data set variation 3/4
# 	Fitting vectorizer...
# 	logistic_regression 1/4
# 	logistic_regression 2/4
# 	logistic_regression 3/4
# 	logistic_regression 4/4
# 	naive_bayes 1/4
# 	naive_bayes 2/4
# 	naive_bayes 3/4
# 	naive_bayes 4/4
# 	random_forest 1/4
# 	random_forest 2/4
# 	random_forest 3/4
# 	random_forest 4/4
# Data set variation 4/4
# 	Fitting vectorizer...
# 	logistic_regression 1/4
# 	logistic_regression 2/4
# 	logistic_regression 3/4
# 	logistic_regression 4/4
# 	naive_bayes 1/4
# 	naive_bayes 2/4
# 	naive_bayes 3/4
# 	naive_bayes 4/4
# 	random_forest 1/4
# 	random_forest 2/4
# 	random_forest 3/4
# 	random_forest 4/4

# %%
for i, params in enumerate(data_sets):
    params_str = {key: str(param) for key, param in params.items()}
    print(f'\nDataset variation {i+1}: {params_str}')
    model_results = results[i]
    for model_name, params in model_results.items():
        print(f'\t{model_name}:')
        for j in range(len(params)):
            print('\t\t{}'.format({
                    'model_params': params[j]['model_params'],
                    'valid_accuracy': params[j]['valid_accuracy']
            }))
# Out:
# Dataset variation 1: {'tokenizer': "<class 'libs.processing.Lemmatizer'>", 'stop_words': 'None', 'min_df': '1'}
# 	logistic_regression:
# 		{'model_params': {'eta0': 0.001, 'alpha': 0.1, 'max_iter': 3, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3259022461512577}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 4, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.2805585934213847}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 5, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.2716412888028939}
# 		{'model_params': {'eta0': 0.01, 'alpha': 0.001, 'max_iter': 8, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.2793808362076218}
# 	naive_bayes:
# 		{'model_params': {'alpha': 0.30000000000000004}, 'valid_accuracy': 0.3786489442247834}
# 		{'model_params': {'alpha': 0.1}, 'valid_accuracy': 0.381088584167578}
# 		{'model_params': {'alpha': 0.5}, 'valid_accuracy': 0.3757886767056448}
# 		{'model_params': {'alpha': 0.9}, 'valid_accuracy': 0.37393791536973164}
# 	random_forest:
# 		{'model_params': {'n_estimators': 700, 'max_depth': 3, 'random_state': 1111}, 'valid_accuracy': 0.2861108774291243}
# 		{'model_params': {'n_estimators': 460, 'max_depth': 5, 'random_state': 1111}, 'valid_accuracy': 0.3009169681164297}
# 		{'model_params': {'n_estimators': 970, 'max_depth': 7, 'random_state': 1111}, 'valid_accuracy': 0.31143265752502736}
# 		{'model_params': {'n_estimators': 320, 'max_depth': 9, 'random_state': 1111}, 'valid_accuracy': 0.3209388407503996}
#
# Dataset variation 2: {'tokenizer': "<class 'libs.processing.Stemmer'>", 'stop_words': 'nltk_english', 'min_df': '2'}
# 	logistic_regression:
# 		{'model_params': {'eta0': 0.001, 'alpha': 0.1, 'max_iter': 3, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3247244889374947}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 4, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3067216286699756}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 5, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.32480861445276354}
# 		{'model_params': {'eta0': 0.01, 'alpha': 0.001, 'max_iter': 8, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.33078152603684696}
# 	naive_bayes:
# 		{'model_params': {'alpha': 0.30000000000000004}, 'valid_accuracy': 0.38134096071338436}
# 		{'model_params': {'alpha': 0.1}, 'valid_accuracy': 0.3825187179271473}
# 		{'model_params': {'alpha': 0.5}, 'valid_accuracy': 0.37906957180112727}
# 		{'model_params': {'alpha': 0.9}, 'valid_accuracy': 0.3786489442247834}
# 	random_forest:
# 		{'model_params': {'n_estimators': 700, 'max_depth': 3, 'random_state': 1111}, 'valid_accuracy': 0.2965424413224531}
# 		{'model_params': {'n_estimators': 460, 'max_depth': 5, 'random_state': 1111}, 'valid_accuracy': 0.30503911836459996}
# 		{'model_params': {'n_estimators': 970, 'max_depth': 7, 'random_state': 1111}, 'valid_accuracy': 0.31950870699083034}
# 		{'model_params': {'n_estimators': 320, 'max_depth': 9, 'random_state': 1111}, 'valid_accuracy': 0.32497686548330107}
#
# Dataset variation 3: {'tokenizer': "<class 'libs.processing.Lemmatizer'>", 'stop_words': 'nltk_english', 'min_df': '2'}
# 	logistic_regression:
# 		{'model_params': {'eta0': 0.001, 'alpha': 0.1, 'max_iter': 3, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3239673593000757}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 4, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3054597459409439}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 5, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.31580718431900395}
# 		{'model_params': {'eta0': 0.01, 'alpha': 0.001, 'max_iter': 8, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3333052914949104}
# 	naive_bayes:
# 		{'model_params': {'alpha': 0.30000000000000004}, 'valid_accuracy': 0.3825187179271473}
# 		{'model_params': {'alpha': 0.1}, 'valid_accuracy': 0.38411710271725413}
# 		{'model_params': {'alpha': 0.5}, 'valid_accuracy': 0.3814250862286532}
# 		{'model_params': {'alpha': 0.9}, 'valid_accuracy': 0.38049970556069657}
# 	random_forest:
# 		{'model_params': {'n_estimators': 700, 'max_depth': 3, 'random_state': 1111}, 'valid_accuracy': 0.29452342895600236}
# 		{'model_params': {'n_estimators': 460, 'max_depth': 5, 'random_state': 1111}, 'valid_accuracy': 0.3036931101202995}
# 		{'model_params': {'n_estimators': 970, 'max_depth': 7, 'random_state': 1111}, 'valid_accuracy': 0.3163960629258854}
# 		{'model_params': {'n_estimators': 320, 'max_depth': 9, 'random_state': 1111}, 'valid_accuracy': 0.31883570286868007}
#
# Dataset variation 4: {'tokenizer': "<class 'libs.processing.Lemmatizer'>", 'stop_words': 'None', 'min_df': '2'}
# 	logistic_regression:
# 		{'model_params': {'eta0': 0.001, 'alpha': 0.1, 'max_iter': 3, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.3257339951207201}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 4, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.2855219988222428}
# 		{'model_params': {'eta0': 0.1, 'alpha': 0.001, 'max_iter': 5, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.2709682846807437}
# 		{'model_params': {'eta0': 0.01, 'alpha': 0.001, 'max_iter': 8, 'loss': 'log', 'random_state': 1111}, 'valid_accuracy': 0.28182047615041644}
# 	naive_bayes:
# 		{'model_params': {'alpha': 0.30000000000000004}, 'valid_accuracy': 0.38016320349962146}
# 		{'model_params': {'alpha': 0.1}, 'valid_accuracy': 0.38066795659123415}
# 		{'model_params': {'alpha': 0.5}, 'valid_accuracy': 0.37839656767897706}
# 		{'model_params': {'alpha': 0.9}, 'valid_accuracy': 0.37427441743080675}
# 	random_forest:
# 		{'model_params': {'n_estimators': 700, 'max_depth': 3, 'random_state': 1111}, 'valid_accuracy': 0.28518549676116767}
# 		{'model_params': {'n_estimators': 460, 'max_depth': 5, 'random_state': 1111}, 'valid_accuracy': 0.29570118616976526}
# 		{'model_params': {'n_estimators': 970, 'max_depth': 7, 'random_state': 1111}, 'valid_accuracy': 0.3132834188609405}
# 		{'model_params': {'n_estimators': 320, 'max_depth': 9, 'random_state': 1111}, 'valid_accuracy': 0.31984520905190544}

# %% [markdown]
# ## Test set results

# %%
best_models = {
    'logistic_regression': 0,
    'naive_bayes': 1,
    'random_forest': 3
}

for model_name, model_index in best_models.items():
    print(f'Best {model_name} test sets accuracies:')
    for i in range(len(results)):
        print(f'\tDataset {i+1}: {results[i][model_name][model_index]["test_accuracy"]:.3f}')

random_predictions = np.random.choice(df.genre.unique(), size=data['y_test'].shape[0])
random_accuracy = sklearn.metrics.accuracy_score(data['y_test'], random_predictions)
print(f'Random classifier test set accuracy: {random_accuracy:.3f}', end='\n\n')
# Out:
# Best logistic_regression test sets accuracies:
# 	Dataset 1: 0.328
# 	Dataset 2: 0.329
# 	Dataset 3: 0.331
# 	Dataset 4: 0.328
# Best naive_bayes test sets accuracies:
# 	Dataset 1: 0.376
# 	Dataset 2: 0.379
# 	Dataset 3: 0.381
# 	Dataset 4: 0.375
# Best random_forest test sets accuracies:
# 	Dataset 1: 0.320
# 	Dataset 2: 0.325
# 	Dataset 3: 0.324
# 	Dataset 4: 0.323
# Random classifier test set accuracy: 0.096

# %%
print('Best model (Naive Bayes) confusion matrix:')
confusion_matrix = results[2]['naive_bayes'][0]['df_test_confusion_matrix']
plt.figure(figsize = (15,12))
plt.xticks(rotation=90)
sns.heatmap(confusion_matrix, annot=True)
# Out:
# Best model (Naive Bayes) confusion matrix:
# <AxesSubplot:>
