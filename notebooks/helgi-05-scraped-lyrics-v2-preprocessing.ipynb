# %% [markdown]
# # Data exploration

# %% [markdown]
# * This notebook explores the dataset scraped-lyrics-v2.csv

# %%
import ast

import numpy as np
import pandas as pd

import sys
sys.path.append("../")

import libs.visual

# %%
df = pd.read_csv('E:\\Repos\\comp550-final-project\\data\\scraped-lyrics-v2.csv')
df
# Out:
#                  artist                        song  \
# 0      The War On Drugs                        Pain
# 1      The War On Drugs             Nothing To Find
# 2      The War On Drugs         Thinking of a Place
# 3      The War On Drugs          Under The Pressure
# 4      The War On Drugs          Under The Pressure
# ...                 ...                         ...
# 79872    James Morrison                So Beautiful
# 79873    James Morrison               Lonely People
# 79874    James Morrison          Slave To The Music
# 79875    James Morrison                     Forever
# 79876    James Morrison  If You Don't Wanna Love Me
#
#                                                   lyrics  \
# 0      Go to bed now I can tell\nPain is on the way o...
# 1      Oh, I'm rising from within\nI see it every mor...
# 2      It was back in Little Bend that I saw you\nLig...
# 3      With a comb down here, it's easy\nBut do you r...
# 4      With a comb down here, it's easy\nBut do you r...
# ...                                                  ...
# 79872  17, way too young for love\nBut I couldn't thi...
# 79873  When you feel alone and need someone\nDo you t...
# 79874  She pulled me in so easily\nRight from the sta...
# 79875  Well my mama used to say\nIf you find a nice g...
# 79876  When you lower me down\nSo deep that I, I can'...
#
#                                     genres          category
# 0      ['Rock Alternativo' 'Indie' 'Folk']  Rock Alternativo
# 1      ['Rock Alternativo' 'Indie' 'Folk']  Rock Alternativo
# 2      ['Rock Alternativo' 'Indie' 'Folk']  Rock Alternativo
# 3      ['Rock Alternativo' 'Indie' 'Folk']  Rock Alternativo
# 4      ['Rock Alternativo' 'Indie' 'Folk']  Rock Alternativo
# ...                                    ...               ...
# 79872       ['Pop/Rock' 'Romântico' 'Pop']        Soul Music
# 79873       ['Pop/Rock' 'Romântico' 'Pop']        Soul Music
# 79874       ['Pop/Rock' 'Romântico' 'Pop']        Soul Music
# 79875       ['Pop/Rock' 'Romântico' 'Pop']        Soul Music
# 79876       ['Pop/Rock' 'Romântico' 'Pop']        Soul Music
#
# [79877 rows x 5 columns]

# %%
# genres are a string, let's convert to a list
df.genres = df.genres.apply(lambda x: ast.literal_eval(x.replace("' ", "', ")))

# %%
# Remove duplicates
df = df.groupby(['artist', 'song']).first().reset_index()
print(f'Remaining songs: {len(df)}')
# Out:
# Remaining songs: 59208

# %%
libs.visual.analyse_lyrics(dataframe=df, n_samples=25, lyrics_length=40, mode='less', random_state=1234)
# Out:
# There are 483 songs with lyrics of 40 characters or less.
# Here are 25 samples:
#
# <index: 32873>
# Instrumental
#
# <index: 56740>
# Instrumental
#
# <index: 40787>
# Instrumental
#
# <index: 37100>
# Instrumental
#
# <index: 45991>
# We're Thirsty
# We are thirsty
#
# <index: 31462>
# Instrumental
#
# <index: 40982>
# [Instrumental]
#
# <index: 27520>
# Instrumental
#
# <index: 3513>
# Instrumental
#
# <index: 30187>
# Instrumental
#
# <index: 44098>
# [This song is an instrumental.]
#
# <index: 1730>
# Instrumental
#
# <index: 7296>
# Instrumental
#
# <index: 28066>
# Instrumental
#
# <index: 14097>
# Instrumental
#
# <index: 6405>
# [Instrumental]
#
# <index: 40422>
# Instrumental
#
# <index: 36817>
# Instrumental
#
# <index: 20893>
# Instrumental
#
# <index: 40373>
# Instrumental
#
# <index: 48189>
# Instrumental
#
# <index: 31370>
# instrumental
#
# <index: 33684>
# Instrumental
#
# <index: 3511>
# Instrumental
#
# <index: 7410>
# Instrumental

# %% [markdown]
# It seems reasonable to remove songs of 40 characters or less, since 24/25 of the samples above are instrumentals

# %%
df = df[df.lyrics.str.len() > 40]

# %%
# Count how many times a song is part of a certain genre
unique, count = np.unique([genre for sublist in df.genres for genre in sublist], return_counts=True)
genre_counts = dict(zip(unique, count))
genre_hist_df = pd.DataFrame.from_dict({
    'genre': [genre for genre, count in genre_counts.items()],
    'count': [count for genre, count in genre_counts.items()]
}).sort_values(by='count', ascending=False).reset_index(drop=True)

pd.options.display.max_rows = 70
genre_hist_df
# Out:
#                genre  count
# 0               Rock  22310
# 1              Indie  10155
# 2          Hard Rock   9712
# 3                R&B   9494
# 4                Pop   9403
# 5        Heavy Metal   8890
# 6            Hip Hop   8842
# 7   Rock Alternativo   8834
# 8            Country   7798
# 9        Black Music   7192
# 10        Soul Music   6239
# 11         Romântico   5658
# 12               Rap   5568
# 13          Pop/Rock   5188
# 14              Folk   4167
# 15             Blues   2218
# 16             Dance   2030
# 17          Hardcore   1617
# 18              Funk   1574
# 19       Electronica   1332
# 20            Grunge   1271
# 21       Progressivo   1146
# 22         Punk Rock   1127
# 23               Axé   1030
# 24             Disco    947
# 25         Soft Rock    801
# 26     Trilha Sonora    779
# 27        Psicodelia    776
# 28            Gótico    761
# 29        Rockabilly    748
# 30  Gospel/Religioso    678
# 31             Metal    598
# 32          Pop/Punk    559
# 33          Pós-Punk    542
# 34              Jazz    508
# 35      J-Pop/J-Rock    335
# 36         Sertanejo    328
# 37          Tecnopop    310
# 38      Classic Rock    291
# 39      Instrumental    270
# 40          New Wave    267
# 41             House    259
# 42           Emocore    256
# 43      Funk Carioca    255
# 44        Piano Rock    239
# 45         Power-Pop    230
# 46            Reggae    157
# 47          Trip-Hop    152
# 48      Velha Guarda    141
# 49            Trance    125
# 50        Surf Music    122
# 51          Clássico    102
# 52        Bossa Nova     98
# 53             Samba     71
# 54         Post-Rock     67
# 55           New Age     50
# 56             Lo-fi     44
# 57        Industrial     33
# 58               MPB     22
# 59               Ska     14
# 60          Chillout     11
# 61      K-Pop/K-Rock      8
# 62       World Music      5
# 63          Infantil      1

# %%
# Define a threshold of "common genres"
frequency_constraint = 1000
common_genres = genre_hist_df[genre_hist_df['count'] > frequency_constraint].genre

# These are songs that have a genre which is in common_genres
df_common_genre_songs = df[pd.DataFrame(df.genres.tolist()).isin(set(common_genres)).any(1).values]
qualifying_song_indices = df.index.isin(list(df_common_genre_songs.index))

# These are songs which are not among the common genres:
non_qualifying_songs = df[~qualifying_song_indices]
print('Songs that are not part of the "common genres":')
non_qualifying_songs
# Out:
# Songs that are not part of the "common genres":
#      artist                                   song  \
# 1170    Air             How Does It Make You Feel?
# 1172    Air                            Seven Stars
# 1173    Air  Somewhere Between Waking And Sleeping
# 1174    Air                          Who Am I Now?
#
#                                                  lyrics  \
# 1170  I am feeling very warm right now\nPlease don't...
# 1172  How long it will take you\nTo reach the stars?...
# 1173  Without blindness, there is no sight\nYou'd se...
# 1174  What do I know, where should I go\nTelling me ...
#
#                                   genres category
# 1170  [Chillout, Instrumental, Trip-Hop]    Indie
# 1172  [Chillout, Instrumental, Trip-Hop]    Indie
# 1173  [Chillout, Instrumental, Trip-Hop]    Indie
# 1174  [Chillout, Instrumental, Trip-Hop]    Indie

# %% [markdown]
# Chillout, Instrumental and Trip-Hop are not among common genres, so these songs wouldn't be considered part of the "common genres". Finally, let's remove any uncommon genres from the genre column:

# %%
df_processed = df_common_genre_songs.copy()
df_processed.genres = df_common_genre_songs.genres.apply(lambda x: sorted(list(set(x).intersection(set(common_genres)))))
genre_counts = df_processed.genres.str.len()

# %%
print(f'Common genres (genres that have at least {frequency_constraint} songs associated with them):')
print(f'\t* Are {100*len(common_genres)/len(genre_hist_df):.2f}% of all genres ({len(common_genres)}/{len(genre_hist_df)})')
print(f'\t* Describe {100*len(df_processed)/len(df):.2f}% of all songs ({len(df_processed)}/{len(df)})')
print(f'\t* Leaves us with {100*len(genre_counts[genre_counts > 1])/len(genre_counts):.2f}% of songs that have 2 or more genres associated ({len(genre_counts[genre_counts > 1])}/{len(genre_counts)})')
# Out:
# Common genres (genres that have at least 1000 songs associated with them):
# 	* Are 37.50% of all genres (24/64)
# 	* Describe 99.99% of all songs (58719/58723)
# 	* Leaves us with 86.52% of songs that have 2 or more genres associated (50802/58719)

# %% [markdown]
# ## Save result

# %%
df_processed.reset_index(drop=True).to_csv('../data/scraped-lyrics-v2-preprocessed.csv', index=False)
