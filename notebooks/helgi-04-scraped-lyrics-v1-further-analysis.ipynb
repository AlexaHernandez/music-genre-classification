# %% [markdown]
# # Data exploration

# %% [markdown]
# Following experimentation in helgi-03-hp-search-first-pass.ipynb (where we didn't perform any filtering), this notebook further explores the data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('E:\\Repos\\comp550-final-project\\data\\scraped-lyrics-v1.csv')
df
# Out:
#          artist                       song  \
# 0      Disperse                     Tether
# 1      Disperse                   Foreword
# 2      Disperse  Touching The Golden Cloud
# 3      Disperse                       Neon
# 4      Disperse                      Kites
# ...         ...                        ...
# 79995   Flyleaf               Broken Wings
# 79996   Flyleaf                 Swept Away
# 79997   Flyleaf               Call You Out
# 79998   Flyleaf            Beautiful Bride
# 79999   Flyleaf                Ocean Waves
#
#                                                   lyrics             genre
# 0      Warm-hearted\nDirections\nWe're off the map\nI...  Alternative Rock
# 1                                         [Instrumental]  Alternative Rock
# 2      Hear in this garden\nHear in this space\nImmer...  Alternative Rock
# 3      Hello dear stranger\nI've got so much to tell ...  Alternative Rock
# 4      Still a headache\nFrom last night\nIt was vali...  Alternative Rock
# ...                                                  ...               ...
# 79995  Thank you for being such a friend to me\nOh, I...              Rock
# 79996  The evil fell from your pretty mouth\nWrapped ...              Rock
# 79997  How can you act like you know\nWhen all you kn...              Rock
# 79998  Unified diversity\nFunctioning as one body\nEv...              Rock
# 79999  So many wasted days\nCome and go like ocean wa...              Rock
#
# [80000 rows x 4 columns]

# %% [markdown]
# Songs per genre available:

# %%
df.groupby('genre').count().lyrics
# Out:
# genre
# Alternative Rock    8000
# Country             8000
# Hard Rock           8000
# Heavy Metal         8000
# Hip-Hop             8000
# Indie               8000
# Pop                 8000
# R&B                 8000
# Rock                8000
# Soul                8000
# Name: lyrics, dtype: int64

# %%
df_v2 = df.groupby(['artist', 'song']).first().reset_index()
unique_artist_song_lyrics = df_v2.groupby('genre').count().lyrics
unique_artist_song_lyrics
# Out:
# genre
# Alternative Rock    7039
# Country             7503
# Hard Rock           6547
# Heavy Metal         6437
# Hip-Hop             7010
# Indie               5685
# Pop                 5190
# R&B                 3083
# Rock                4277
# Soul                7027
# Name: lyrics, dtype: int64

# %%
print(f'When we only keep one copy of each song (remove duplicates), we see that we end up with {sum(unique_artist_song_lyrics)} songs.')
# Out:
# When we only keep one copy of each song (remove duplicates), we see that we end up with 59798 songs.

# %% [markdown]
# As we can see, there are quite a lot of songs that are duplicates, that were assigned to different genres on Vagalume. We should extract all of the genres associated with each song and create a v2 of the dataset such that we can have a more accurate representation of which song is part of which genres. See **helgi-05-scraped-lyrics-v2.ipynb**. Finally, we note that some songs are tabs:

# %%
tab_lyrics = df[df.lyrics.str.contains('.*[\|:][\-]+[0-9a-zA-Z]+[\-]+.*', regex=True)]
print(f'There are at least {len(tab_lyrics)} songs that are tabs')
# Out:
# There are at least 32 songs that are tabs

# %% [markdown]
# ## Identify outliers and invalid data

# %% [markdown]
# Lyrics may be missing or be of invalid format (tabs instead of lyrics). Let's identify these entries

# %% [markdown]
# Distribution of lyric lengths:

# %%
lyrics_lengths = df['lyrics'].str.len()
lyrics_lengths.describe()
# Out:
# count    80000.000000
# mean      1295.329463
# std        811.373017
# min          7.000000
# 25%        777.000000
# 50%       1112.000000
# 75%       1588.000000
# max      33531.000000
# Name: lyrics, dtype: float64

# %% [markdown]
# As we can tell, some lyric entries are very short (7 characters) while others are very long (33531 characters). Let's explore them:

# %%
def analyse_lyrics(length, n_samples, mode='less', random_state=None, max_print=50):
    if mode.lower() == 'less':
        candidates = lyrics_lengths[lyrics_lengths < length]
    elif mode.lower() == 'more':
        candidates = lyrics_lengths[lyrics_lengths > length]
    else:
        raise ValueError('mode can only be "less" or "more"')

    print(f'There are {len(candidates)} songs with lyrics of {length} characters or {mode}.')
    print(f'Here are {n_samples} samples:', end='\n\n')

    for index, entry in candidates.sample(n_samples, random_state=random_state).iteritems():
        lyrics = df.iloc[index].lyrics
        if len(lyrics) >= max_print:
            lyrics = lyrics[:max_print] + f' <... {len(lyrics) - max_print} more chars>'
        print(f'<index: {index}>\n{lyrics}', end='\n\n')

analyse_lyrics(length=70, mode='less', n_samples=25, random_state=1234)
# Out:
# There are 746 songs with lyrics of 70 characters or less.
# Here are 25 samples:
#
# <index: 55546>
# (Instrumental)
#
# <index: 22426>
# (Instrumental)
#
# <index: 63290>
# [This song is an instrumental.]
#
# <index: 32979>
# Instrumental
#
# <index: 75593>
# All you have to do
# All you have to do
# Ahhhhhhh Ahh <... 3 more chars>
#
# <index: 17062>
# Instrumental
#
# <index: 17015>
# Instrumental
#
# <index: 40479>
# Instrumental
#
# <index: 17867>
# Instrumental
#
# <index: 16793>
# Instrumental
#
# <index: 51881>
# [Instrumental]
#
# <index: 78947>
# Instrumental
#
# <index: 65567>
# Instrumental
#
# <index: 8272>
# Instrumental
#
# <index: 79758>
# Everywhere I go
# Swallowed up inside
#
# <index: 7002>
# Instrumental
#
# <index: 27928>
# Instrumental
#
# <index: 3778>
# (Instrumental song)
#
# <index: 54607>
# [This song is an instrumental.]
#
# <index: 19428>
# Instrumental
#
# <index: 29534>
# Instrumental
#
# <index: 70435>
# I just need the first note
# La-la-la
# La-la-la
# La-la <... 12 more chars>
#
# <index: 48638>
# Instrumental
#
# <index: 33890>
# [Instrumental]
#
# <index: 58538>
# Oh
# Oh
# Oh
# Oh...

# %% [markdown]
# Informally, we can see that 21 of those 25 samples (84%) don't have lyrics specified. Let's note that for the future.
#
# Next, let's look at the top 1% of the longest lyrics:

# %%
longest_1_perc = int(lyrics_lengths.quantile(0.99))
analyse_lyrics(length=longest_1_perc, mode='more', n_samples=25, random_state=1234, max_print=100)
# Out:
# There are 800 songs with lyrics of 3990 characters or more.
# Here are 25 samples:
#
# <index: 42411>
# [Verse 1 - Lil’ Wayne]
# Uh, I like a long hair thick red-bone
# open up her legs to filet mignon that p <... 4548 more chars>
#
# <index: 40239>
# [Rihanna]
# I remember when the world was just me and my mama
# All I waited for was to wear my dresses  <... 3914 more chars>
#
# <index: 47891>
# And say yeah..and say yeah..and say yeah..
# [Wiz Khalifa]
# One Night town
# My niggas round
# Throwin’ mon <... 4118 more chars>
#
# <index: 38198>
# [Part I Odysseus' Theme / Overture]
# [music / orchestration - Romeo]
# [instrumental]
# [Part II - Journe <... 4097 more chars>
#
# <index: 46377>
# Lill Wayne
# Remix Baby
# Lean Clap
# If you bout paper
# Holla at a holla at a holla at a playa
# Cell phone  <... 3938 more chars>
#
# <index: 57919>
# I'm not a rapper I'm a singer with a flow
# I've got a habit for spitting quicker lyrics you know
# You' <... 6337 more chars>
#
# <index: 40528>
# Yeah
# We cop new timepieces when these fools deny Jesus
# Hate is a sin, dog, be real, I got my hand on <... 4106 more chars>
#
# <index: 40795>
# Intro: The Genius/GZA (from "Clan in Da Front")
# Niggaz on the left, brag shit to death
# Now hoods on  <... 4229 more chars>
#
# <index: 31592>
# Another day, another dollar
# Your nigga's home
# Don't make me holler
# Is anybody home?
# Hmm, I guess not <... 4284 more chars>
#
# <index: 69876>
# Alright gang let's start from number one
# Let's throw down till it's done
# Let's get this thing to wor <... 4193 more chars>
#
# <index: 66482>
# Uh
# Stepped out on bail, I did a Diddy-bop
# I had to tilt my hat at the city cop
# I walk away free 'cau <... 4182 more chars>
#
# <index: 43719>
# [Intro - Akon (Chamillionaire)]
# See I remember I was just loner
# (I was just a loner, I was just a lo <... 4205 more chars>
#
# <index: 41495>
# Make yaself, Don't break yaself
# Make yaself, Don't break yaself
# Be afraid cause I'm something your'r <... 4323 more chars>
#
# <index: 68588>
# This song right here, is dedicated to the president of the United States of America
# Y'all might know <... 5718 more chars>
#
# <index: 47566>
# (Rippa on the beat, bitch)
# Trap back jumpin', I don't wanna hear nothin'
# Trap, trap back jumpin', I  <... 4367 more chars>
#
# <index: 40382>
# (50 Cent talkin')
# Hey Em, you know you my favorite white boy right?
# I owe you for this one
# Ive been  <... 4664 more chars>
#
# <index: 46009>
# Fat Man Scoop, Crooklyn Clan
# Timbaland, Timbaland
# Fat Man Scoop, Crooklyn Clan
# Timbaland, Timbaland
#  <... 4044 more chars>
#
# <index: 43794>
# Yeah, yeah
# We The Best Music!
# I worked my whole life for this one
# Yeah
# Another one
# Yeah
# DJ Khaled!
# S <... 3917 more chars>
#
# <index: 42665>
# [Jay-Z]
# Uh-huh uh yeah, gi-gi-geyeah
# Time to come up, hold my own weight, defend my crown
# Gots to lo <... 4417 more chars>
#
# <index: 46301>
# That's where you niggas got it fucked up and twisted
# They ain't scared about just a regular black ma <... 4859 more chars>
#
# <index: 43075>
# (feat. The Game, Jim Jones, Block)
# [Intro:]
# [Deep Voice:] Hustlenomics
# [The Game:] eh joc
# [Yung Joc: <... 4451 more chars>
#
# <index: 61315>
# I walk up in that motherfucker like, get what you want
# Ayy, let me get that
# Gift shop, gift shop, ye <... 3999 more chars>
#
# <index: 68463>
# Hollygrove, Hollywood, Hollygrove, Hollywood
# Too Hollygrove to go Hollywood
# Find out where your pare <... 3953 more chars>
#
# <index: 45747>
# f/ 2Pac
# [Ja Rule]
# Rest in peace to my nigga Stretch, my nigga 'Pac
# So much pain
# Uhh.. yeah, huh, yea <... 4011 more chars>
#
# <index: 44096>
# 21
# I feel like the motherfuckin' Grim Reaper
# The biggest smoke blower
# Put a motherfuckin' chimney on <... 4518 more chars>

# %% [markdown]
# Informally, these look fine, but we could experiment with using an upper bound for how many characters we consider from a song, to not produce overly busy embeddings.

# %% [markdown]
# Interestingly enough, most of those very long lyrics are Hip-Hop:

# %%
candidates = lyrics_lengths[lyrics_lengths > longest_1_perc]
samples = candidates.sample(25, random_state=1234)
df.iloc[samples.index].genre
# Out:
# 42411        Hip-Hop
# 40239        Hip-Hop
# 47891        Hip-Hop
# 38198    Heavy Metal
# 46377        Hip-Hop
# 57919            Pop
# 40528        Hip-Hop
# 40795        Hip-Hop
# 31592           Soul
# 69876            R&B
# 66482            R&B
# 43719        Hip-Hop
# 41495        Hip-Hop
# 68588            R&B
# 47566        Hip-Hop
# 40382        Hip-Hop
# 46009        Hip-Hop
# 43794        Hip-Hop
# 42665        Hip-Hop
# 46301        Hip-Hop
# 43075        Hip-Hop
# 61315            Pop
# 68463            R&B
# 45747        Hip-Hop
# 44096        Hip-Hop
# Name: genre, dtype: object

# %% [markdown]
# Finally, let's look at the top 100 longest entries:

# %%
lyrics_lengths.nlargest(100)
# Out:
# 23832    33531
# 72425    33531
# 23981    17006
# 76479    17006
# 42945    13408
#          ...
# 68588     5818
# 7991      5808
# 40577     5787
# 7901      5761
# 73245     5761
# Name: lyrics, Length: 100, dtype: int64

# %%
analyse_lyrics(length=5760, mode='more', n_samples=100, random_state=1234, max_print=100)
# Out:
# There are 100 songs with lyrics of 5760 characters or more.
# Here are 100 samples:
#
# <index: 43588>
# [Royce Da 5'9"]
# First verse, uh, I'm on 'til I'm on a island
# My life's ridin' on the autobahn on aut <... 6173 more chars>
#
# <index: 43195>
# One Blood - (feat. Jim Jones, Snoop Dogg, Nas, T.I., Fat Joe, lil WayneNORE, Jadakiss, Styles P, Fab <... 10859 more chars>
#
# <index: 68523>
# [Turk]
# Come on, come on
# Come on, come on, come on, come on, come on
# I roll with a bunch of untamed g <... 5858 more chars>
#
# <index: 46505>
# At these up late times, hardcore funkateers before the bop gun.
# We unleash you a positive light. The <... 6752 more chars>
#
# <index: 76479>
# Intro
# |------------|-------------------------------|-----------------------------|
# |------------|--- <... 16906 more chars>
#
# <index: 58008>
# I was born inside a small town
# I've lost that state of mind
# Learned to sing inside the Lord's house
#  <... 5855 more chars>
#
# <index: 68615>
# Baby understand me now
# If sometimes you see that I'm mad
# Don't you know no one alive can always be a <... 5795 more chars>
#
# <index: 42470>
# Hey
# If you know what's good
# (If you know what's good)
# Haters gon' say it's fake
# So real
# Haters gon'  <... 6556 more chars>
#
# <index: 43435>
# [Intro: Big Sean]
# I look up
# Yeah and I take my time
# I'mma take my time, woah
# Power moves only
# [Verse <... 7087 more chars>
#
# <index: 43650>
# [Chorus]
# we hear em talking dine
# but we still
# on the grind
# crawlin' slow
# tippin' dine
# but we do it f <... 5887 more chars>
#
# <index: 43113>
# Live by the code, die by the code, never been a ho
# Bury me before I sell my soul
# Live by the code, d <... 6574 more chars>
#
# <index: 46304>
# Got love for everyone in the business
# But everyone in my business
# Tell me, how should I talk when ev <... 6066 more chars>
#
# <index: 46696>
# Yeah (for your eyes)
# For your eyes only (for your eyes)
# For your eyes only, for your eyes only
# (for  <... 7425 more chars>
#
# <index: 74594>
# (Reed)
# Left Voice (Morrison, Tucker)
# candy screen wrappers of silkscreen fantastic, requiring memori <... 10951 more chars>
#
# <index: 46140>
# Bandana wrapped-wrapped 'round your head
# The bandana wrapped 'round your head
# Fuck niggas, they scar <... 5800 more chars>
#
# <index: 70065>
# Intro: Mase
# Yo yo, this Mase, youknowhati'msayin?
# You got niggaz that don't like me for whatever rea <... 6020 more chars>
#
# <index: 74647>
# Waldo Jeffers had reached his limit. It was now Mid-August which meant he had
# been separated from Ma <... 7670 more chars>
#
# <index: 7899>
# Interviewer: Well... Where are you coming from?
# Blaise Bailey Finnegan III: (pause) Well... I don't  <... 6370 more chars>
#
# <index: 61987>
# Strange fear I ain't felt for years
# The boys comin' and I'm close to tears
# I can't let go
# Of you now <... 7334 more chars>
#
# <index: 68537>
# [intro: kendrick lamar]
# I got a story to tell, you know that I cherish thee
# Hope it ain't too many f <... 6653 more chars>
#
# <index: 23632>
# From the CD 'Master of Reality'
# Written by Iommi/Ward/Butler/Osbourne
# Warner Bros. Records 2562-2
# Tu <... 11121 more chars>
#
# <index: 44867>
# [Turk]
# Come on, come on
# Come on, come on, come on, come on, come on
# I roll with a bunch of untamed g <... 5858 more chars>
#
# <index: 42922>
# [Swizz Beatz]
# One hand in the air if you don’t really care
# two hands in the air if you don’t really  <... 5731 more chars>
#
# <index: 70068>
# Intro: Mase
# Yo yo, this Mase, youknowhati'msayin?
# You got niggaz that don't like me for whatever rea <... 6020 more chars>
#
# <index: 66164>
# [Swizz Beatz]
# One hand in the air if you don’t really care
# two hands in the air if you don’t really  <... 5731 more chars>
#
# <index: 66079>
# [Intro: Jay-Z (Kanye)]
# [laughing]
# Yo fuck you, Kanye, first and foremost
# For making me do this shit. <... 13308 more chars>
#
# <index: 46683>
# And wherever we go
# And whatever we do
# And whatever we see
# And whoever we be
# It don't matter
# It don't <... 11907 more chars>
#
# <index: 47660>
# [DJ Khaled]
# We the best
# Who
# We nigga
# We the best
# This the remix
# The I'm so hood remix
# I'm making mov <... 6130 more chars>
#
# <index: 66510>
# Got love for everyone in the business
# But everyone in my business
# Tell me, how should I talk when ev <... 6066 more chars>
#
# <index: 43853>
# I'm So Hood [Remix]
# Khaled
# Compositor: Não Disponível
# DJ Khaled
# We the best
# Who
# We nigga
# We the best <... 6257 more chars>
#
# <index: 7991>
# | Tuning: Standard (low to high: e a d g b e)
# | Tempo: Fast
# ---------------------------------------- <... 5708 more chars>
#
# <index: 46738>
# Yeah (for your eyes)
# For your eyes only (for your eyes)
# For your eyes only, for your eyes only
# (for  <... 7425 more chars>
#
# <index: 23832>
# Notation legend.-
# / = slide
# . = palm mute
# b = bend to note («=half, f=full, f«=one & a half, etc.)
# b <... 33431 more chars>
#
# <index: 74591>
# (Reed)
# Left Voice (Morrison, Tucker)
# candy screen wrappers of silkscreen fantastic, requiring memori <... 10951 more chars>
#
# <index: 46252>
# His hair, wack, his gear, wack
# His jewelry, wack, his foot stance, wack
# The way that he talks, wack
#  <... 6546 more chars>
#
# <index: 66038>
# [Intro: Johnny "Guitar" Watson & Junie Morrison]
# La di da da-a, da-a (I like this flavor)
# La da da d <... 6298 more chars>
#
# <index: 43349>
# [Intro: Big Sean]
# I look up
# Yeah and I take my time
# I'mma take my time, woah
# Power moves only
# [Verse <... 7087 more chars>
#
# <index: 21977>
# You know I got my granddad's pistol in that antique cabinet (Mm)
# I be having more interesting conver <... 8470 more chars>
#
# <index: 45329>
# [DJ Khaled]
# We the best
# Who
# We nigga
# We the best
# This the remix
# The I'm so hood remix
# I'm making mov <... 6130 more chars>
#
# <index: 66458>
# His hair, wack, his gear, wack
# His jewelry, wack, his foot stance, wack
# The way that he talks, wack
#  <... 6546 more chars>
#
# <index: 40854>
# (Ol Dirty Bastard)
# What y'all thought y'all wasn't gon' see me?
# I'm the Osirus of this shit
# Wu-Tang  <... 5925 more chars>
#
# <index: 40577>
# Aiyyo Fat Joe, it's your first album right?
# You comin out the South Bronx
# Time to let brothers know  <... 5687 more chars>
#
# <index: 58312>
# He....He....just freak,freak,freak
# shake your monkey,monkey,monkey,monkey,
# monkey,monkey,monkey(shak <... 5958 more chars>
#
# <index: 70062>
# [P. Diddy - talking]
# Ten years
# Yo the sun don't shine forever
# But as long as it's here then we might <... 6392 more chars>
#
# <index: 41777>
# [ Fresh Prince ]
# Yo Jeff, what's shakin, man?
# [ Jazzy Jeff ]
# What's up, dude?
# [ Fresh Prince ]
# Hey m <... 5737 more chars>
#
# <index: 13345>
# Bm9 A/B (an A works as well)
# |-9-------------------------------------|-X---------------------------- <... 10940 more chars>
#
# <index: 43698>
# [Hook]
# You ain't gotta go home (you aint gotta go)
# but you gotta get the hell up out of here
# If you  <... 6326 more chars>
#
# <index: 22081>
# You know I got my granddad's pistol in that antique cabinet (Mm)
# I be having more interesting conver <... 8470 more chars>
#
# <index: 43607>
# [Intro:]
# I'm coming home, I'm coming home
# Tell the world I'm coming home
# Let the rain wash away
# All  <... 7883 more chars>
#
# <index: 38608>
# From the CD 'Master of Reality'
# Written by Iommi/Ward/Butler/Osbourne
# Warner Bros. Records 2562-2
# Tu <... 11121 more chars>
#
# <index: 43737>
# [Chorus:]
# Welcome to my hood, everybody know everybody and if I got it everybody got it, ugh
# Welcome <... 6609 more chars>
#
# <index: 40848>
# (Ol Dirty Bastard)
# What y'all thought y'all wasn't gon' see me?
# I'm the Osirus of this shit
# Wu-Tang  <... 5925 more chars>
#
# <index: 42050>
# [Royce Da 5'9"]
# First verse, uh, I'm on 'til I'm on a island
# My life's ridin' on the autobahn on aut <... 6030 more chars>
#
# <index: 46112>
# I know my nigga gangsta got it on wild willa
# Uptown consist of drug dealers, and thugs
# For the junki <... 6829 more chars>
#
# <index: 66483>
# It's one of the crazier stories we've heard of, guys (I know)
# As it's unfolding it's like
# Fuck Tory  <... 5770 more chars>
#
# <index: 43030>
# [Swizz Beatz]
# One hand in the air if you don’t really care
# two hands in the air if you don’t really  <... 5731 more chars>
#
# <index: 73841>
# So we left Beirut Willa and I
# He headed East to Baghdad and the rest of it
# I set out North
# I walked  <... 6863 more chars>
#
# <index: 13327>
# Bm9 A/B (an A works as well)
# |-9-------------------------------------|-X---------------------------- <... 10940 more chars>
#
# <index: 68588>
# This song right here, is dedicated to the president of the United States of America
# Y'all might know <... 5718 more chars>
#
# <index: 43085>
# [The Game talking]
# What the fuck is all this noise?
# He from Cali he can't rap
# He ain't better than t <... 9719 more chars>
#
# <index: 44881>
# [intro: kendrick lamar]
# I got a story to tell, you know that I cherish thee
# Hope it ain't too many f <... 6653 more chars>
#
# <index: 31808>
# We got a wonderful show 4 y'all 2night, uh (Alright, I love it)
# But first off, before we get 2 the b <... 6295 more chars>
#
# <index: 73245>
# well...where are you coming from?
# ...well...i don't like the way the country's ran,
# don't you know,  <... 5661 more chars>
#
# <index: 39679>
# [Part I]
# so where do we begin
# and what else can we say?
# when the lines are all drawn
# what should we  <... 5834 more chars>
#
# <index: 42904>
# [Intro: Johnny "Guitar" Watson & Junie Morrison]
# La di da da-a, da-a (I like this flavor)
# La da da d <... 6298 more chars>
#
# <index: 43792>
# [Chorus:]
# Welcome to my hood, everybody know everybody and if I got it everybody got it, ugh
# Welcome <... 6609 more chars>
#
# <index: 46376>
# [Jae Millz:]
# I get kited till the haze gone
# That's why my lungs look like they could be related to G <... 5748 more chars>
#
# <index: 32393>
# You know I got my granddad's pistol in that antique cabinet (Mm)
# I be having more interesting conver <... 8470 more chars>
#
# <index: 46804>
# And wherever we go
# And whatever we do
# And whatever we see
# And whoever we be
# It don't matter
# It don't <... 11907 more chars>
#
# <index: 31724>
# Yeah, one of 'em.
# Yeah, one of them nice breezy motherfuckers
# Nigger. what U lookin' 4 nigger?
# Oh ho <... 5835 more chars>
#
# <index: 40814>
# [Intro:]
# *sounds of fighting*
# [M]- Method Man
# [R]- Raekwon
# [G]- Ghostface Killah
# [U]- U-God
# [M] Yo w <... 5744 more chars>
#
# <index: 7901>
# well...where are you coming from?
# ...well...i don't like the way the country's ran,
# don't you know,  <... 5661 more chars>
#
# <index: 7980>
# The song is split up into 5 parts as describe by the CD booklet,
# and I've tabbed each one as it's ow <... 11606 more chars>
#
# <index: 3437>
# Sing
# Baby, you've been going so crazy
# Lately nothing seems to be going right
# Solo, why do you have t <... 8804 more chars>
#
# <index: 23981>
# Intro
# |------------|-------------------------------|-----------------------------|
# |------------|--- <... 16906 more chars>
#
# <index: 57919>
# I'm not a rapper I'm a singer with a flow
# I've got a habit for spitting quicker lyrics you know
# You' <... 6337 more chars>
#
# <index: 75869>
# Cluster One
# What Do You Want From Me
# As you look around this room tonight
# Settle in your seat and di <... 8519 more chars>
#
# <index: 43117>
# Live by the code, die by the code, never been a ho
# Bury me before I sell my soul
# Live by the code, d <... 6574 more chars>
#
# <index: 43373>
# This that clipse sample
# Fuck that talking let the clip slam 'em
# Yellow bands around them hundreds yo <... 10906 more chars>
#
# <index: 74637>
# Waldo Jeffers had reached his limit. It was now Mid-August which meant he had
# been separated from Ma <... 7670 more chars>
#
# <index: 44861>
# lil wayne- where The cash At
# (feat. Currency & Remy Ma)
# [Intro]
# You Catch My Girl Legs Open Betta Sm <... 8414 more chars>
#
# <index: 78729>
# Introduçao guitarra 1
# E|-------------------------------------------|
# B|----------------10------8---- <... 11527 more chars>
#
# <index: 66056>
# [Swizz Beatz]
# One hand in the air if you don’t really care
# two hands in the air if you don’t really  <... 5731 more chars>
#
# <index: 68517>
# lil wayne- where The cash At
# (feat. Currency & Remy Ma)
# [Intro]
# You Catch My Girl Legs Open Betta Sm <... 8414 more chars>
#
# <index: 58311>
# Imma be, imma be - imma, imma, imma be
# Imma be, imma be - imma, imma, imma be
# Imma be, imma be - imm <... 6133 more chars>
#
# <index: 46277>
# It's one of the crazier stories we've heard of, guys (I know)
# As it's unfolding it's like
# Fuck Tory  <... 5770 more chars>
#
# <index: 73243>
# Interviewer: Well... Where are you coming from?
# Blaise Bailey Finnegan III: (pause) Well... I don't  <... 6370 more chars>
#
# <index: 72425>
# Notation legend.-
# / = slide
# . = palm mute
# b = bend to note («=half, f=full, f«=one & a half, etc.)
# b <... 33431 more chars>
#
# <index: 43688>
# [Song borrows the beat from Bun B's "Get Throwed"]
# [Chorus: Chamillionaire]
# Sorry but I'm real busy  <... 5951 more chars>
#
# <index: 42945>
# [Intro: Jay-Z (Kanye)]
# [laughing]
# Yo fuck you, Kanye, first and foremost
# For making me do this shit. <... 13308 more chars>
#
# <index: 42055>
# [Chainsaw revving]
# Ha-ha-ha-ha-ha-ha-ha-ha
# [Eminem]
# Got a shit-eatin' grin
# Bitch, show me them itty- <... 7115 more chars>
#
# <index: 42040>
# [Chainsaw revving]
# Ha-ha-ha-ha-ha-ha-ha-ha
# [Eminem]
# Got a shit-eatin' grin
# Bitch, show me them itty- <... 7115 more chars>
#
# <index: 44567>
# Shit, niggas got me higher than a motherfucker off up in here, man.
# Damn, the fuck y'all get this we <... 6102 more chars>
#
# <index: 32436>
# You know I got my granddad's pistol in that antique cabinet (Mm)
# I be having more interesting conver <... 8470 more chars>
#
# <index: 42043>
# [Royce da 5'9"]
# Ryan's a homicidal misfit, I write the solution of biophysics
# On the side of a cliff <... 6421 more chars>
#
# <index: 66248>
# Yayo
# Yaayo!
# Ya-Yo
# (Flo-Rida)
# Hey, I coulda been born any place in the world when I turned a day old
#  <... 6049 more chars>
#
# <index: 45259>
# [DJ Khaled]
# We the best
# Who
# We nigga
# We the best
# This the remix
# The I'm so hood remix
# I'm making mov <... 6130 more chars>
#
# <index: 43397>
# This that clipse sample
# Fuck that talking let the clip slam 'em
# Yellow bands around them hundreds yo <... 10906 more chars>
#
# <index: 68585>
# Yeah, I go by the name of cassidy the hustler
# And I brought two of my niggas with me
# And we about to <... 6141 more chars>
#
# <index: 43819>
# [Intro: DJ Khaled]
# DJ Khaled!
# [Verse 1: Jadakiss]
# Pat them down count the money, let 'em see the wor <... 5878 more chars>

# %% [markdown]
# Above we observe that the following indexes are tabs (not lyrics). We can therefore remove them: 76479, 7991, 13345, 13327, 23981, 78729 and 72425. Example:

# %%
df.iloc[76479].lyrics[:200]
# Out:
# 'Intro\n|------------|-------------------------------|-----------------------------|\n|------------|-------------------------------|-----------------------------|\n|------------|-2--------5----0--2-------'

# %% [markdown]
# # Conclusion
#
# * We should consider removing songs with low amounts of lyrics characters (the example of <= 70 characters was observed above: 746 songs). About 84% of these are instrumentals or don't have the lyrics specified
# * Some songs are tabs, maybe we want to process these separately?
